# %%
import sqlite3
import pandas as pd
import matplotlib.pyplot as plt

# %%
db_path = "../data/btc_prices.sqlite3"
conn = sqlite3.connect(db_path)

# %%
df = pd.read_sql_query("SELECT * FROM price_snapshots", conn)

# %%
df.head()
# Out:
#    id asset  measurement_timestamp observed_market_type  spot_price  \
# 0   1   BTC          1774458045657                 perp         NaN
# 1   2   BTC          1774458045719                 perp         NaN
# 2   3   BTC          1774458045657                 spot     71306.5
# 3   4   BTC          1774458045719                 spot     71306.5
# 4   5   BTC          1774458045855                 perp     71306.5
#
#    perp_price  spot_microprice  perp_microprice  filtered_price         basis  \
# 0     71306.5              NaN     71306.858977    35238.866543  35238.866543
# 1     71306.5              NaN     71306.834381    35455.008028  35455.008028
# 2     71306.5     71306.858977     71306.834381    69709.376791   1678.771777
# 3     71306.5     71306.834381     71306.834381    70513.206148    919.886508
# 4     71306.5     71306.834381     71306.787590    70508.053688    869.028456
#
#    recorded_at_ms filtered_timestamp observed_asset observed_bid_price  \
# ...

# %%
df["measurement_timestamp"] = pd.to_datetime(df["measurement_timestamp"], unit="ms")
df["recorded_at"] = pd.to_datetime(df["recorded_at_ms"], unit="ms")

# %%
df.head()
# Out:
#    id asset   measurement_timestamp observed_market_type  spot_price  \
# 0   1   BTC 2026-03-25 17:00:45.657                 perp         NaN
# 1   2   BTC 2026-03-25 17:00:45.719                 perp         NaN
# 2   3   BTC 2026-03-25 17:00:45.657                 spot     71306.5
# 3   4   BTC 2026-03-25 17:00:45.719                 spot     71306.5
# 4   5   BTC 2026-03-25 17:00:45.855                 perp     71306.5
#
#    perp_price  spot_microprice  perp_microprice  filtered_price         basis  \
# 0     71306.5              NaN     71306.858977    35238.866543  35238.866543
# 1     71306.5              NaN     71306.834381    35455.008028  35455.008028
# 2     71306.5     71306.858977     71306.834381    69709.376791   1678.771777
# 3     71306.5     71306.834381     71306.834381    70513.206148    919.886508
# 4     71306.5     71306.834381     71306.787590    70508.053688    869.028456
#
#    recorded_at_ms filtered_timestamp observed_asset observed_bid_price  \
# ...

# %%
df = (
      df.drop(columns=["id", "asset"])
        .assign(measurement_timestamp=lambda x: pd.to_datetime(x["measurement_timestamp"], unit="ms"))
        .set_index("measurement_timestamp")
        .sort_index()
  )

# %%
df.head()
# Out:
#                         observed_market_type  spot_price  perp_price  \
# measurement_timestamp
# 2026-03-25 17:00:45.657                 perp         NaN     71306.5
# 2026-03-25 17:00:45.657                 spot     71306.5     71306.5
# 2026-03-25 17:00:45.719                 perp         NaN     71306.5
# 2026-03-25 17:00:45.719                 spot     71306.5     71306.5
# 2026-03-25 17:00:45.855                 perp     71306.5     71306.5
#
#                          spot_microprice  perp_microprice  filtered_price  \
# measurement_timestamp
# 2026-03-25 17:00:45.657              NaN     71306.858977    35238.866543
# 2026-03-25 17:00:45.657     71306.858977     71306.834381    69709.376791
# 2026-03-25 17:00:45.719              NaN     71306.834381    35455.008028
# 2026-03-25 17:00:45.719     71306.834381     71306.834381    70513.206148
# 2026-03-25 17:00:45.855     71306.834381     71306.787590    70508.053688
#
# ...

# %%
df = df.iloc[60:]

# %%
df.head(20)
# Out:
#                         observed_market_type  spot_price  perp_price  \
# measurement_timestamp
# 2026-03-25 17:00:49.610                 spot     71306.5     71306.5
# 2026-03-25 17:00:49.610                 perp     71306.5     71306.5
# 2026-03-25 17:00:49.727                 perp     71306.5     71306.5
# 2026-03-25 17:00:49.727                 spot     71306.5     71306.5
# 2026-03-25 17:00:50.066                 perp     71306.5     71306.5
# 2026-03-25 17:00:50.066                 spot     71306.5     71306.5
# 2026-03-25 17:00:50.130                 perp     71306.5     71306.5
# 2026-03-25 17:00:50.130                 spot     71306.5     71306.5
# 2026-03-25 17:00:50.190                 spot     71306.5     71306.5
# 2026-03-25 17:00:50.190                 perp     71306.5     71306.5
# 2026-03-25 17:00:50.278                 perp     71306.5     71306.5
# 2026-03-25 17:00:50.278                 spot     71306.5     71306.5
# ...

# %%
plt.plot(df.spot_price, label="spot")
plt.plot(df.spot_microprice, label="micro")
plt.plot(df.filtered_price, label="latent")
plt.legend()

# %%
plt.plot(df.basis)

# %%
sample = df.iloc[50:250].copy().reset_index(drop=True)

plt.figure(figsize=(10, 4))
plt.plot(sample["spot_price"], label="spot")
plt.plot(sample["perp_price"], label="perp")
plt.plot(sample["spot_microprice"], label="micro")
plt.plot(sample["filtered_price"], label="latent")

plt.ticklabel_format(style='plain', axis='y', useOffset=False)
plt.legend()
plt.show()

# %%
plt.plot(df.basis)
plt.plot((df.spot_price - df.perp_price))

# %% [markdown]
# ## Now lets test prediction using latent
