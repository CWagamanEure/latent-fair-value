# %%
import pandas as pd

# %%
df = pd.read_parquet("../data/research-datasets/latent-fair-value/btc/asset_context_snapshots/part-btc_prices_20260331T222251Z-e5f28d114c1ceb6d55e1421cbe95a4c9-7.parquet")

# %%
df.head()
# Out:
#    id asset measurement_timestamp observed_market_type observed_asset  \
# 0   1   BTC                  None                 perp            BTC
# 1   2   BTC                  None                 perp            BTC
# 2   3   BTC                  None                 perp            BTC
# 3   4   BTC                  None                 perp            BTC
# 4   5   BTC                  None                 perp            BTC
#
#    funding_rate  open_interest  oracle_price  mark_price  mid_price   premium  \
# 0     -0.000016    27799.81850       67238.0     67195.0    67190.5 -0.000696
# 1     -0.000016    27799.82444       67238.0     67195.0    67190.5 -0.000695
# 2     -0.000016    27799.89038       67238.0     67195.0    67190.5 -0.000684
# 3     -0.000016    27799.89038       67238.0     67195.0    67190.5 -0.000699
# 4     -0.000016    27799.94066       67238.0     67195.0    67190.5 -0.000699
#
# ...

# %% [markdown]
# # What I need to test
#
# - Test whether lagged funding predicts future basis compression
# - Test whether lagged OI growth predicts future basis widening
# - Test whether high OI makes basis more persistent
# - Test whether extreme funding predicts reversals
# - Test whether funding and OI interact nonlinearly
# - Test whether time-to-next-funding affects basis dynamics
# - Test whether microprice improves short-horizon basis prediction
# - Test whether spread/depth explain temporary dislocations
# - Test whether equilibrium basis and temporary dislocation should be modeled separately
# - Test whether regime-switching improves basis forecasts
